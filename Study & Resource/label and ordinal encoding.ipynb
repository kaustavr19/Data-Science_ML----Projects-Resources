# %% [markdown]
# # Label Encoding & Ordinal Encoding

# %% [markdown]
# ## Label Encoding

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option("display.max_rows", None)

# %%
df = pd.read_csv(r"K:\KaustavR25\SKILLZ\Data Science & Analysis, ML\Data-Science_ML----Projects-Resources-main\Study & Resource\train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df2 = df[['KitchenQual', 'BldgType']]

# %%
le = LabelEncoder()

# %%
le.fit_transform(df2["BldgType"])
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df2["BldgType_le"] = le.fit_transform(df2["BldgType"])
df2
# Out:
# <ipython-input-8-00771b8383af>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["BldgType_le"] = le.fit_transform(df2["BldgType"])
#         Gd     1Fam            0
# 948           Gd     1Fam            0
# 949           Gd     1Fam            0
# 950           Gd     1Fam            0
# 951           TA     1Fam            0
# 952           TA     1Fam            0
# 953           TA     1Fam            0
# 954           TA   Duplex            2
# 955           TA   Duplex            2
# 956           TA   TwnhsE            4
# 957           TA     1Fam            0
# 958           Gd     1Fam            0
# 959           Gd    Twnhs            3
# 960           TA     1Fam            0
# 961           TA     1Fam            0
# ...

# %%
df["BldgType"].value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %% [markdown]
# ## Ordinal Encoding

# %%
df["KitchenQual"].value_counts()
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64

# %%
order_label = {"Ex":4, "Gd":3, "TA":2, "Fa":1}

# %%
df2["KitchenQual_oe"] = df2["KitchenQual"].map(order_label)
# Out:
# <ipython-input-13-417238fe005e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["KitchenQual_oe"] = df2["KitchenQual"].map(order_label)

# %%
df2
# Out:
#   1Fam            0               3
# 1097          Gd   TwnhsE            4               3
# 1098          TA     1Fam            0               2
# 1099          TA     1Fam            0               2
# 1100          Fa     1Fam            0               1
# 1101          TA     1Fam            0               2
# 1102          TA     1Fam            0               2
# 1103          TA     1Fam            0               2
# 1104          TA   TwnhsE            4               2
# 1105          Gd     1Fam            0               3
# 1106          Gd     1Fam            0               3
# 1107          Gd     1Fam            0               3
# 1108          TA     1Fam            0               2
# 1109          Gd     1Fam            0               3
# 1110          TA     1Fam            0               2
# 1111          TA     1Fam            0               2
# 1112          TA     1Fam            0               2
# ...
